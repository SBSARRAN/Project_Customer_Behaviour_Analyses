# %%
import mysql.connector
mydb = mysql.connector.connect(
        host = "localhost",
        user = "root",
        password = "12345",
        database = "Customer_Behaviour_Analyses",
        autocommit = True)
mycursor = mydb.cursor()

# %%
import pandas as pd
df = pd.read_csv(r'C:/Sarran Guvi/Guvi/MDT47/Project Customer Behaviour Analyses/Data Set/customer_journey.csv')
df
# Out:
#     JourneyID  CustomerID  ProductID   VisitDate        Stage    Action  \
# 0           1          64         18  2024-06-10     Checkout  Drop-off
# 1           2          94         11  2025-07-09     Checkout  Drop-off
# 2           3          34          8  2024-06-14  ProductPage      View
# 3           4          33         18  2025-05-28     Checkout  Drop-off
# 4           5          91         10  2023-02-11     Homepage     Click
# ..        ...         ...        ...         ...          ...       ...
# 95         96          22          9  2024-07-28  ProductPage      View
# 96         97          92         19  2025-05-26     homepage      View
# 97         98          95          8  2025-05-25     Homepage     Click
# 98         99          58         16  2024-07-06     Checkout  Purchase
# 99        100          92         10  2024-04-06  ProductPage      View
#
#     Duration
# 0        NaN
# 1        NaN
# 2      235.0
# 3        NaN
# 4      156.0
# ..       ...
# ...

# %%
values = [tuple(x) for x in df.to_numpy()]
values
# Out:
# [(1, 64, 18, '2024-06-10', 'Checkout', 'Drop-off', nan),
#  (2, 94, 11, '2025-07-09', 'Checkout', 'Drop-off', nan),
#  (3, 34, 8, '2024-06-14', 'ProductPage', 'View', 235.0),
#  (4, 33, 18, '2025-05-28', 'Checkout', 'Drop-off', nan),
#  (5, 91, 10, '2023-02-11', 'Homepage', 'Click', 156.0),
#  (6, 54, 11, '2025-12-19', 'Homepage', 'View', 264.0),
#  (7, 80, 4, '2023-08-25', 'Homepage', 'View', 298.0),
#  (8, 99, 10, '2025-07-03', 'ProductPage', 'View', 287.0),
#  (9, 31, 4, '2025-06-13', 'ProductPage', 'View', 278.0),
#  (10, 44, 16, '2025-04-23', 'ProductPage', 'View', 30.0),
#  (11, 23, 12, '2023-08-22', 'Checkout', 'Drop-off', nan),
#  (12, 97, 12, '2023-07-28', 'ProductPage', 'View', 227.0),
#  (13, 83, 5, '2024-06-20', 'Homepage', 'View', 223.0),
#  (14, 14, 13, '2025-11-01', 'ProductPage', 'View', 13.0),
#  (15, 9, 1, '2025-11-04', 'ProductPage', 'View', 292.0),
#  (16, 14, 16, '2024-07-17', 'Homepage', 'View', 46.0),
#  (17, 67, 2, '2025-12-11', 'Homepage', 'View', 185.0),
# ...

# %%
mycursor.execute("CREATE TABLE Customer_journey (JourneyID int,CustomerID int,ProductID int,VisitDate Date,	Stage varchar(50),Action varchar(50),Duration varchar(50));")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 mycursor.execute("CREATE TABLE Customer_journey (JourneyID int,CustomerID int,ProductID int,VisitDate Date,	Stage varchar(50),Action varchar(50),Duration varchar(50));")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mysql\connector\cursor.py:416, in MySQLCursor.execute(self, operation, params, map_results)
#     408 self._executed_list = self._stmt_partition["single_stmts"]
#     409 self._executed = (
#     410     self._stmt_partition["single_stmts"].popleft()
#     411     if map_results
#     412     else self._stmt_partition["mappable_stmt"]
#     413 )
#     415 self._handle_result(
# --> 416     self._connection.cmd_query(
#     417         self._stmt_partition["mappable_stmt"],
#     418         read_timeout=self._read_timeout,
#     419         write_timeout=self._write_timeout,
# ...

# %%
sql = """ insert into Customer_journey (JourneyID , 
CustomerID ,
ProductID , 
VisitDate ,
Stage , 
Action , 
Duration ) values (%s,%s,%s,%s,%s,%s,%s)"""

# %%
mycursor.executemany(sql,values)

# %%
mycursor.execute("select * from customer_journey ();")

# %%
data = mycursor.fetchall()
for i in data :
    print(i)
# Out:
# (1, 64, 18, '2024-06-10', 'Checkout', 'Drop-off', None)
# (2, 94, 11, '2025-07-09', 'Checkout', 'Drop-off', None)
# (3, 34, 8, '2024-06-14', 'ProductPage', 'View', 235.0)
# (4, 33, 18, '2025-05-28', 'Checkout', 'Drop-off', None)
# (5, 91, 10, '2023-02-11', 'Homepage', 'Click', 156.0)
# (6, 54, 11, '2025-12-19', 'Homepage', 'View', 264.0)
# (7, 80, 4, '2023-08-25', 'Homepage', 'View', 298.0)
# (8, 99, 10, '2025-07-03', 'ProductPage', 'View', 287.0)
# (9, 31, 4, '2025-06-13', 'ProductPage', 'View', 278.0)
# (10, 44, 16, '2025-04-23', 'ProductPage', 'View', 30.0)
# (11, 23, 12, '2023-08-22', 'Checkout', 'Drop-off', None)
# (12, 97, 12, '2023-07-28', 'ProductPage', 'View', 227.0)
# (13, 83, 5, '2024-06-20', 'Homepage', 'View', 223.0)
# (14, 14, 13, '2025-11-01', 'ProductPage', 'View', 13.0)
# (15, 9, 1, '2025-11-04', 'ProductPage', 'View', 292.0)
# (16, 14, 16, '2024-07-17', 'Homepage', 'View', 46.0)
# (17, 67, 2, '2025-12-11', 'Homepage', 'View', 185.0)
# ...

# %%
df2 = pd.read_csv(r'C:/Sarran Guvi/Guvi/MDT47/Project Customer Behaviour Analyses/Data Set/customer_reviews.csv')
df2
# Out:
#     ReviewID  CustomerID  ProductID  ReviewDate  Rating  \
# 0          1          77         18  2023-12-23       3
# 1          2          80         19  2024-12-25       5
# 2          3          50         13  2025-01-26       4
# 3          4          78         15  2025-04-21       3
# 4          5          64          2  2023-07-16       3
# ..       ...         ...        ...         ...     ...
# 95        96          19         13  2023-09-02       3
# 96        97          64          6  2024-01-19       3
# 97        98          96          3  2025-11-20       5
# 98        99          79         16  2025-01-29       2
# 99       100           9          2  2025-06-20       3
#
#                                            ReviewText
# 0             Average  experience,  nothing  special.
# 1                      The  quality  is    top-notch.
# 2             Five  stars  for  the  quick  delivery.
# 3            Good  quality,  but  could  be  cheaper.
# ...

# %%
values = [tuple(x) for x in df2.to_numpy()]
values
# Out:
# [(1, 77, 18, '2023-12-23', 3, 'Average  experience,  nothing  special.'),
#  (2, 80, 19, '2024-12-25', 5, 'The  quality  is    top-notch.'),
#  (3, 50, 13, '2025-01-26', 4, 'Five  stars  for  the  quick  delivery.'),
#  (4, 78, 15, '2025-04-21', 3, 'Good  quality,  but  could  be  cheaper.'),
#  (5, 64, 2, '2023-07-16', 3, 'Average  experience,  nothing  special.'),
#  (6, 81, 1, '2025-12-21', 4, 'Customer  support  was  very  helpful.'),
#  (7, 16, 1, '2024-01-29', 3, 'Average  experience,  nothing  special.'),
#  (8, 55, 8, '2024-08-15', 5, 'The  quality    is  top-notch.'),
#  (9, 3, 13, '2023-09-01', 4, 'I  love  this  product,  will  buy  again!'),
#  (10, 78, 6, '2024-06-17', 5, 'Excellent  product,  highly  recommend!'),
#  (11, 54, 9, '2023-07-17', 4, 'Great  purchase,  very  satisfied.'),
#  (12, 77, 2, '2025-01-13', 2, 'Product  did    not  meet  my  expectations.'),
#  (13, 93, 6, '2024-08-20', 5, 'Great  purchase,  very  satisfied.'),
# ...

# %%
mycursor.execute("CREATE TABLE customers_reviews (ReviewID int, CustomerID int ,ProductID int,ReviewDate DATE , Rating int , ReviewText VARCHAR(255) );")

# %%
sql = """ insert into customers_reviews (ReviewID , CustomerID  ,ProductID ,ReviewDate  , Rating  , 
ReviewText ) values (%s,%s,%s,%s,%s,%s)  """

# %%
mycursor.executemany(sql,values)

# %%
df3 = pd.read_csv(r'C:/Sarran Guvi/Guvi/MDT47/Project Customer Behaviour Analyses/Data Set/customers.csv')
df3
# Out:
#     CustomerID      CustomerName                         Email  Gender  Age  \
# 0            1     Emma Anderson     emma.anderson@example.com    Male   50
# 1            2       Sarah Brown       sarah.brown@example.com  Female   37
# 2            3  Robert Hernandez  robert.hernandez@example.com  Female   26
# 3            4      David Garcia      david.garcia@example.com    Male   25
# 4            5       Emma Miller       emma.miller@example.com  Female   41
# ..         ...               ...                           ...     ...  ...
# 95          96    Emily Gonzalez    emily.gonzalez@example.com  Female   38
# 96          97   Emily Rodriguez   emily.rodriguez@example.com  Female   51
# 97          98       Chris Lopez       chris.lopez@example.com  Female   55
# 98          99   Laura Hernandez   laura.hernandez@example.com    Male   41
# 99         100        Jane Brown        jane.brown@example.com  Female   45
#
#     GeographyID
# 0             2
# 1             4
# ...

# %%
mycursor.execute("create table customers (CustomerID int ,Customer_Name varchar(255),Email varchar(255),Gender	varchar(50),Age int,GeographyID int);")

# %%
values = [tuple(x) for x in df3.to_numpy()]
values
# Out:
# [(1, 'Emma Anderson', 'emma.anderson@example.com', 'Male', 50, 2),
#  (2, 'Sarah Brown', 'sarah.brown@example.com', 'Female', 37, 4),
#  (3, 'Robert Hernandez', 'robert.hernandez@example.com', 'Female', 26, 6),
#  (4, 'David Garcia', 'david.garcia@example.com', 'Male', 25, 8),
#  (5, 'Emma Miller', 'emma.miller@example.com', 'Female', 41, 4),
#  (6, 'Daniel Rodriguez', 'daniel.rodriguez@example.com', 'Male', 31, 7),
#  (7, 'Laura Miller', 'laura.miller@example.com', 'Male', 35, 7),
#  (8, 'James Gonzalez', 'james.gonzalez@example.com', 'Female', 18, 8),
#  (9, 'Emily Thomas', 'emily.thomas@example.com', 'Male', 29, 10),
#  (10, 'Chris Davis', 'chris.davis@example.com', 'Female', 46, 2),
#  (11, 'Emma Garcia', 'emma.garcia@example.com', 'Male', 54, 10),
#  (12, 'James Lopez', 'james.lopez@example.com', 'Female', 43, 7),
#  (13, 'David Wilson', 'david.wilson@example.com', 'Male', 50, 1),
#  (14, 'Olivia Wilson', 'olivia.wilson@example.com', 'Male', 60, 4),
# ...

# %%
sql = """ insert into customers (CustomerID,customer_Name,Email,Gender,Age,GeographyID)
values (%s,%s,%s,%s,%s,%s)"""

# %%
mycursor.executemany(sql,values)

# %%
df4 = pd.read_csv(r'C:/Sarran Guvi/Guvi/MDT47/Project Customer Behaviour Analyses/Data Set/engagement_data.csv')
df4
# Out:
#     EngagementID  ContentID ContentType  Likes EngagementDate  CampaignID  \
# 0              1         39        Blog    190     2023-08-30           1
# 1              2         48        Blog    114     2023-03-28          18
# 2              3         16       video     32     2023-12-08           7
# 3              4         43       Video     17     2025-01-21          19
# 4              5         16  newsletter    306     2024-02-21           6
# ..           ...        ...         ...    ...            ...         ...
# 95            96         17        Blog     32     2024-07-15          14
# 96            97         34        blog      3     2025-07-01          16
# 97            98         44        blog      0     2025-08-20          11
# 98            99         26        Blog    119     2024-04-15          17
# 99           100         32       Video     34     2024-05-05          15
#
#     ProductID ViewsClicksCombined
# 0           9            1883-671
# ...

# %%
df4.dtypes
# Out:
# EngagementID            int64
# ContentID               int64
# ContentType            object
# Likes                   int64
# EngagementDate         object
# CampaignID              int64
# ProductID               int64
# ViewsClicksCombined    object
# dtype: object

# %%
mycursor.execute("create table engagement_data (EngagementID int,ContentID int,	ContentType	varchar(50),Likes int,EngagementDate DATE,CampaignID int,ProductID int,	ViewsClicksCombined varchar(10)) ;")

# %%
values = [tuple(x) for x in df4.to_numpy()]
values
# Out:
# [(1, 39, 'Blog', 190, '2023-08-30', 1, 9, '1883-671'),
#  (2, 48, 'Blog', 114, '2023-03-28', 18, 20, '5280-532'),
#  (3, 16, 'video', 32, '2023-12-08', 7, 14, '1905-204'),
#  (4, 43, 'Video', 17, '2025-01-21', 19, 20, '2766-257'),
#  (5, 16, 'newsletter', 306, '2024-02-21', 6, 15, '5116-1524'),
#  (6, 32, 'Socialmedia', 648, '2023-06-18', 18, 19, '8237-1641'),
#  (7, 33, 'SOCIALMEDIA', 1, '2025-10-01', 12, 2, '750-34'),
#  (8, 47, 'Blog', 1, '2025-03-31', 17, 6, '891-35'),
#  (9, 48, 'blog', 123, '2024-03-19', 13, 16, '5571-1527'),
#  (10, 4, 'Blog', 25, '2023-12-03', 15, 15, '4279-297'),
#  (11, 38, 'Socialmedia', 29, '2024-05-26', 19, 6, '4297-234'),
#  (12, 29, 'socialmedia', 396, '2023-06-15', 3, 10, '7877-2037'),
#  (13, 14, 'video', 12, '2025-02-04', 12, 18, '1796-136'),
#  (14, 2, 'Socialmedia', 317, '2023-08-26', 16, 2, '6837-2251'),
#  (15, 16, 'Socialmedia', 0, '2025-10-20', 6, 19, '36-1'),
#  (16, 2, 'SOCIALMEDIA', 276, '2023-07-06', 17, 16, '5980-1227'),
# ...

# %%
sql = """ insert into  engagement_data (EngagementID,ContentID	,ContentType,Likes,	EngagementDate,	CampaignID,	ProductID,	ViewsClicksCombined)
values (%s,%s,%s,%s,%s,%s,%s,%s)"""

# %%
mycursor.executemany(sql,values)

# %%
df5 = pd.read_csv(r'C:/Sarran Guvi/Guvi/MDT47/Project Customer Behaviour Analyses/Data Set/geography.csv')

# %%
mycursor.execute("create table geography (GeographyID int,Country varchar(50),	City varchar(50));")

# %%
values = values = [tuple(x) for x in df5.to_numpy()]
values
# Out:
# [(1, 'UK', 'London'),
#  (2, 'Germany', 'Berlin'),
#  (3, 'France', 'Paris'),
#  (4, 'Spain', 'Madrid'),
#  (5, 'Italy', 'Rome'),
#  (6, 'Netherlands', 'Amsterdam'),
#  (7, 'Belgium', 'Brussels'),
#  (8, 'Sweden', 'Stockholm'),
#  (9, 'Switzerland', 'Zurich'),
#  (10, 'Austria', 'Vienna')]

# %%
sql = """ insert into geography (GeographyID,Country,City) values (%s,%s,%s)"""

# %%
mycursor.executemany(sql,values)

# %%
df6 = pd.read_csv(r'C:/Sarran Guvi/Guvi/MDT47/Project Customer Behaviour Analyses/Data Set/products.csv')
df6
# Out:
#     ProductID      ProductName Category   Price
# 0           1    Running Shoes   Sports  223.75
# 1           2  Fitness Tracker   Sports  196.68
# 2           3         Yoga Mat   Sports  485.32
# 3           4        Dumbbells   Sports   26.21
# 4           5      Soccer Ball   Sports   41.26
# 5           6    Tennis Racket   Sports   36.07
# 6           7       Basketball   Sports  225.12
# 7           8  Football Helmet   Sports   44.75
# 8           9   Baseball Glove   Sports  327.36
# 9          10       Golf Clubs   Sports   81.59
# 10         11        Ski Boots   Sports  340.20
# 11         12       Ice Skates   Sports   37.56
# 12         13     Swim Goggles   Sports  145.97
# 13         14   Cycling Helmet   Sports  472.32
# 14         15    Climbing Rope   Sports  410.17
# 15         16            Kayak   Sports  259.40
# 16         17        Surfboard   Sports  275.43
# 17         18       Volleyball   Sports   42.80
# 18         19     Hockey Stick   Sports  173.83
# ...

# %%
mycursor.execute("create table products(ProductID int,	ProductName varchar(50)	,Category varchar(50),	Price FLOAT )")

# %%
values = [tuple(x) for x in df6.to_numpy()]
values
# Out:
# [(1, 'Running Shoes', 'Sports', 223.75),
#  (2, 'Fitness Tracker', 'Sports', 196.68),
#  (3, 'Yoga Mat', 'Sports', 485.32),
#  (4, 'Dumbbells', 'Sports', 26.21),
#  (5, 'Soccer Ball', 'Sports', 41.26),
#  (6, 'Tennis Racket', 'Sports', 36.07),
#  (7, 'Basketball', 'Sports', 225.12),
#  (8, 'Football Helmet', 'Sports', 44.75),
#  (9, 'Baseball Glove', 'Sports', 327.36),
#  (10, 'Golf Clubs', 'Sports', 81.59),
#  (11, 'Ski Boots', 'Sports', 340.2),
#  (12, 'Ice Skates', 'Sports', 37.56),
#  (13, 'Swim Goggles', 'Sports', 145.97),
#  (14, 'Cycling Helmet', 'Sports', 472.32),
#  (15, 'Climbing Rope', 'Sports', 410.17),
#  (16, 'Kayak', 'Sports', 259.4),
#  (17, 'Surfboard', 'Sports', 275.43),
#  (18, 'Volleyball', 'Sports', 42.8),
#  (19, 'Hockey Stick', 'Sports', 173.83),
#  (20, 'Boxing Gloves', 'Sports', 262.32)]

# %%
sql = """insert into products (ProductID,ProductName,Category,Price) values (%s,%s,%s,%s)"""

# %%
mycursor.executemany(sql,values)

# %%
# What Factors are influencing customer engagement
mycursor.execute("select likes,productname,price,contenttype from engagement_data as a left join products as b on a.productid=b.productid where a.likes> 200 ;")

# %%
data = mycursor.fetchall()
for i in data:
    print(i)
# Out:
# (306, 'Climbing Rope', 410.17, 'newsletter')
# (648, 'Hockey Stick', 173.83, 'Socialmedia')
# (396, 'Golf Clubs', 81.59, 'socialmedia')
# (317, 'Fitness Tracker', 196.68, 'Socialmedia')
# (276, 'Kayak', 259.4, 'SOCIALMEDIA')
# (357, 'Kayak', 259.4, 'video')
# (400, 'Running Shoes', 223.75, 'Video')
# (449, 'Climbing Rope', 410.17, 'Newsletter')
# (373, 'Ski Boots', 340.2, 'Video')
# (215, 'Dumbbells', 26.21, 'Video')
# (840, 'Football Helmet', 44.75, 'Blog')
# (459, 'Cycling Helmet', 472.32, 'Video')
# (657, 'Running Shoes', 223.75, 'BLOG')
# (545, 'Yoga Mat', 485.32, 'Blog')
# (397, 'Kayak', 259.4, 'video')
# (595, 'Baseball Glove', 327.36, 'Video')
# (389, 'Surfboard', 275.43, 'Video')

# %%
df = pd.DataFrame(data,columns=['likes','productname','price','contenttype'])
df
# Out:
#     likes      productname   price  contenttype
# 0     306    Climbing Rope  410.17   newsletter
# 1     648     Hockey Stick  173.83  Socialmedia
# 2     396       Golf Clubs   81.59  socialmedia
# 3     317  Fitness Tracker  196.68  Socialmedia
# 4     276            Kayak  259.40  SOCIALMEDIA
# 5     357            Kayak  259.40        video
# 6     400    Running Shoes  223.75        Video
# 7     449    Climbing Rope  410.17   Newsletter
# 8     373        Ski Boots  340.20        Video
# 9     215        Dumbbells   26.21        Video
# 10    840  Football Helmet   44.75         Blog
# 11    459   Cycling Helmet  472.32        Video
# 12    657    Running Shoes  223.75         BLOG
# 13    545         Yoga Mat  485.32         Blog
# 14    397            Kayak  259.40        video
# 15    595   Baseball Glove  327.36        Video
# 16    389        Surfboard  275.43        Video

# %%
# At what stage customers dropping off in their journey ?

# %%
mycursor.execute(" select stage,action,productid from Customer_journey where action = 'Drop-off';")

# %%
Data = mycursor.fetchall()
for i in Data:
    print(i)
# Out:
# ('Checkout', 'Drop-off', 18)
# ('Checkout', 'Drop-off', 11)
# ('Checkout', 'Drop-off', 18)
# ('Checkout', 'Drop-off', 12)
# ('Checkout', 'Drop-off', 20)
# ('Checkout', 'Drop-off', 6)
# ('Checkout', 'Drop-off', 11)
# ('Checkout', 'Drop-off', 17)
# ('checkout', 'Drop-off', 20)
# ('Checkout', 'Drop-off', 9)
# ('checkout', 'Drop-off', 11)
# ('Checkout', 'Drop-off', 7)
# ('Checkout', 'Drop-off', 20)
# ('Checkout', 'Drop-off', 8)

# %%
df = pd.DataFrame(Data,columns = ['stage','action','Product_ID'])
df
# Out:
#        stage    action  Product_ID
# 0   Checkout  Drop-off          18
# 1   Checkout  Drop-off          11
# 2   Checkout  Drop-off          18
# 3   Checkout  Drop-off          12
# 4   Checkout  Drop-off          20
# 5   Checkout  Drop-off           6
# 6   Checkout  Drop-off          11
# 7   Checkout  Drop-off          17
# 8   checkout  Drop-off          20
# 9   Checkout  Drop-off           9
# 10  checkout  Drop-off          11
# 11  Checkout  Drop-off           7
# 12  Checkout  Drop-off          20
# 13  Checkout  Drop-off           8

# %%
# How do customers reviews impact purchasing behaviour:

# %%
mycursor.execute("select  a.productid,stage,action,rating,reviewtext,c.productname,c.price from Customer_journey as a inner join Customers_reviews as b on a.productid=b.productid left join products as c on a.productid = c.productid where a.action = 'Drop-off';")

# %%
Data = mycursor.fetchall()
for i in Data:
    print(i)
# Out:
# (18, 'Checkout', 'Drop-off', 3, 'Average  experience,  nothing  special.', 'Volleyball', 42.8)
# (18, 'Checkout', 'Drop-off', 3, 'Average  experience,  nothing  special.', 'Volleyball', 42.8)
# (8, 'Checkout', 'Drop-off', 5, 'The  quality    is  top-notch.', 'Football Helmet', 44.75)
# (6, 'Checkout', 'Drop-off', 5, 'Excellent  product,  highly  recommend!', 'Tennis Racket', 36.07)
# (9, 'Checkout', 'Drop-off', 4, 'Great  purchase,  very  satisfied.', 'Baseball Glove', 327.36)
# (6, 'Checkout', 'Drop-off', 5, 'Great  purchase,  very  satisfied.', 'Tennis Racket', 36.07)
# (11, 'checkout', 'Drop-off', 5, 'Great  purchase,  very  satisfied.', 'Ski Boots', 340.2)
# (11, 'Checkout', 'Drop-off', 5, 'Great  purchase,  very  satisfied.', 'Ski Boots', 340.2)
# (11, 'Checkout', 'Drop-off', 5, 'Great  purchase,  very  satisfied.', 'Ski Boots', 340.2)
# (17, 'Checkout', 'Drop-off', 5, 'Excellent  product,  highly  recommend!', 'Surfboard', 275.43)
# ...

# %%
df = pd.DataFrame(Data,columns = ['productid','stage','action','rating','reviewtext','productname','price' ])
df
# Out:
#     productid     stage    action  rating  \
# 0          18  Checkout  Drop-off       3
# 1          18  Checkout  Drop-off       3
# 2           8  Checkout  Drop-off       5
# 3           6  Checkout  Drop-off       5
# 4           9  Checkout  Drop-off       4
# 5           6  Checkout  Drop-off       5
# 6          11  checkout  Drop-off       5
# 7          11  Checkout  Drop-off       5
# 8          11  Checkout  Drop-off       5
# 9          17  Checkout  Drop-off       5
# 10          6  Checkout  Drop-off       1
# 11         18  Checkout  Drop-off       5
# 12         18  Checkout  Drop-off       5
# 13         20  Checkout  Drop-off       4
# 14         20  checkout  Drop-off       4
# 15         20  Checkout  Drop-off       4
# 16         11  checkout  Drop-off       4
# 17         11  Checkout  Drop-off       4
# 18         11  Checkout  Drop-off       4
# 19          6  Checkout  Drop-off       4
# 20          8  Checkout  Drop-off       5
# ...

# %%
mycursor.execute("select  a.productid,stage,action,rating,reviewtext,c.productname,c.price from Customer_journey as a inner join Customers_reviews as b on a.productid=b.productid left join products as c on a.productid = c.productid where a.action = 'purchase';")

# %%
Data = mycursor.fetchall()
for i in Data:
    print(i)

# %%
df= pd.DataFrame(Data,columns = ['productid','stage','action','rating','reviewtext','productname','price' ])
df
# Out:
# Empty DataFrame
# Columns: [productid, stage, action, rating, reviewtext, productname, price]
# Index: []

# %%
# Which products,locations and customer segments are performing well?

# %%
mycursor.execute("select  Customer_Name, country,city, c.action ,d.productname from customers as a left join geography as b on a.GeographyID = b.GeographyID left join Customer_journey as c on a.customerid = c.customerid left join products as d on c.productid = d.productid where c.action = 'purchase';")

# %%
Data = mycursor.fetchall()
for i in Data:
    print(i)
# Out:
# ('Daniel Thomas', 'Germany', 'Berlin', 'Purchase', 'Fitness Tracker')
# ('John Gonzalez', 'UK', 'London', 'Purchase', 'Surfboard')
# ('Chris Johnson', 'Spain', 'Madrid', 'Purchase', 'Surfboard')
# ('Jane Williams', 'Austria', 'Vienna', 'Purchase', 'Kayak')
# ('John Jones', 'Netherlands', 'Amsterdam', 'Purchase', 'Climbing Rope')
# ('Alex Rodriguez', 'Sweden', 'Stockholm', 'Purchase', 'Climbing Rope')

# %%
df = pd.DataFrame(Data,columns=['Customer_Name', 'country','city', 'action' ,'productname'])
df
# Out:
#     Customer_Name      country       city    action      productname
# 0   Daniel Thomas      Germany     Berlin  Purchase  Fitness Tracker
# 1   John Gonzalez           UK     London  Purchase        Surfboard
# 2   Chris Johnson        Spain     Madrid  Purchase        Surfboard
# 3   Jane Williams      Austria     Vienna  Purchase            Kayak
# 4      John Jones  Netherlands  Amsterdam  Purchase    Climbing Rope
# 5  Alex Rodriguez       Sweden  Stockholm  Purchase    Climbing Rope

# %%
# Customer Leaving negative comments for certain products
mycursor.execute("select CustomerID,Rating,ReviewText,productname from Customers_reviews as a left join products as b on a.ProductID = b.ProductID where a.rating <= 2 ;")

# %%
Low_Rating_products = mycursor.fetchall()
for i in Low_Rating_products:
    print(i)
# Out:
# (77, 2, 'Product  did    not  meet  my  expectations.', 'Fitness Tracker')
# (34, 1, 'I  had  a  bad  experience  with  this  product.', 'Tennis Racket')
# (62, 1, 'The  product  stopped  working  after  a  month.', 'Dumbbells')
# (41, 2, 'Disappointed  with  the  performance.', 'Golf Clubs')
# (78, 2, 'The  product    is  okay,  but  the  instructions  were  unclear.', 'Basketball')
# (35, 2, 'Average  experience,  nothing  special.', 'Surfboard')
# (34, 1, 'Not  worth  the  money.', 'Yoga Mat')
# (84, 2, 'The  product  arrived    late.', 'Climbing Rope')
# (79, 2, 'Average  experience,  nothing  special.', 'Kayak')

# %%
df = pd.DataFrame(Low_Rating_products,columns = ['CustomerID','Rating','ReviewText','productname'])
df
# Out:
#    CustomerID  Rating                                         ReviewText  \
# 0          77       2       Product  did    not  meet  my  expectations.
# 1          34       1   I  had  a  bad  experience  with  this  product.
# 2          62       1   The  product  stopped  working  after  a  month.
# 3          41       2              Disappointed  with  the  performance.
# 4          78       2  The  product    is  okay,  but  the  instructi...
# 5          35       2            Average  experience,  nothing  special.
# 6          34       1                            Not  worth  the  money.
# 7          84       2                     The  product  arrived    late.
# 8          79       2            Average  experience,  nothing  special.
#
#        productname
# 0  Fitness Tracker
# 1    Tennis Racket
# 2        Dumbbells
# 3       Golf Clubs
# 4       Basketball
# 5        Surfboard
# 6         Yoga Mat
# 7    Climbing Rope
# 8            Kayak

# %%
# identify key complaints and improvement areas

# %%
df
# Out:
#    CustomerID  Rating                                         ReviewText  \
# 0          77       2       Product  did    not  meet  my  expectations.
# 1          34       1   I  had  a  bad  experience  with  this  product.
# 2          62       1   The  product  stopped  working  after  a  month.
# 3          41       2              Disappointed  with  the  performance.
# 4          78       2  The  product    is  okay,  but  the  instructi...
# 5          35       2            Average  experience,  nothing  special.
# 6          34       1                            Not  worth  the  money.
# 7          84       2                     The  product  arrived    late.
# 8          79       2            Average  experience,  nothing  special.
#
#        productname
# 0  Fitness Tracker
# 1    Tennis Racket
# 2        Dumbbells
# 3       Golf Clubs
# 4       Basketball
# 5        Surfboard
# 6         Yoga Mat
# 7    Climbing Rope
# 8            Kayak

# %%
# Find Pattern between negative review and product performance

# %%
mycursor.execute("select a.customerid,a.productid,action,rating,reviewtext from Customer_journey as a left join Customers_reviews as b on a.customerid=b.customerid where a.action = 'purchase'; ")

# %%
Data = mycursor.fetchall()
for i in Data:
    print(i)
# Out:
# (17, 2, 'Purchase', 5, 'Five  stars  for  the  quick  delivery.')
# (17, 2, 'Purchase', 4, 'Shipping  was  fast  and  the  item  was  well-packaged.')
# (42, 17, 'Purchase', None, None)
# (46, 17, 'Purchase', None, None)
# (89, 15, 'Purchase', 3, 'Not    worth  the  money.')
# (79, 15, 'Purchase', 2, 'Average  experience,  nothing  special.')
# (58, 16, 'Purchase', None, None)

# %%
# Actual Customers purchased and actual reviews
df = pd.DataFrame(Data,columns = ['customerid','productid','action','rating','reviewtext'])
df
# Out:
#    customerid  productid    action  rating  \
# 0          17          2  Purchase     5.0
# 1          17          2  Purchase     4.0
# 2          42         17  Purchase     NaN
# 3          46         17  Purchase     NaN
# 4          89         15  Purchase     3.0
# 5          79         15  Purchase     2.0
# 6          58         16  Purchase     NaN
#
#                                           reviewtext
# 0            Five  stars  for  the  quick  delivery.
# 1  Shipping  was  fast  and  the  item  was  well...
# 2                                               None
# 3                                               None
# 4                          Not    worth  the  money.
# 5            Average  experience,  nothing  special.
# 6                                               None

# %%
mycursor.execute("select customer_name,a.customerid,a.productid,action,rating,reviewtext from Customer_journey as a left join Customers_reviews as b on a.customerid=b.customerid left join customers as c on a.customerid = c.customerid  where a.action != 'purchase' and reviewtext is not null order by rating asc")

# %%
Data = mycursor.fetchall()
for i in Data:
    print(i)
# Out:
# ('Daniel Miller', 34, 8, 'View', 1, 'I  had  a  bad  experience  with  this  product.')
# ('Daniel Miller', 34, 8, 'View', 1, 'Not  worth  the  money.')
# ('David Lopez', 77, 6, 'Drop-off', 2, 'Product  did    not  meet  my  expectations.')
# ('Olivia Smith', 78, 20, 'View', 2, 'The  product    is  okay,  but  the  instructions  were  unclear.')
# ('David Lopez', 77, 6, 'Drop-off', 3, 'Average  experience,  nothing  special.')
# ('John Thomas', 60, 19, 'Click', 3, 'The  quality  is  top-notch.')
# ('Olivia Smith', 78, 20, 'View', 3, 'Good  quality,  but  could  be  cheaper.')
# ('Sarah Martinez', 64, 2, 'Click', 3, 'Average  experience,  nothing  special.')
# ('Sarah Martinez', 64, 6, 'Click', 3, 'Average  experience,  nothing  special.')
# ('Sarah Martinez', 64, 18, 'Drop-off', 3, 'Average  experience,  nothing  special.')
# ('David Garcia', 4, 12, 'View', 3, 'Great  purchase,  very  satisfied.')
# ('Sarah Brown', 2, 5, 'View', 3, 'Not  worth  the  money.')
# ...

# %%
# Customers below are not purchased the products and left an reviews
df = pd.DataFrame(Data,columns = ['customer_name','customerid','productid','action','rating','reviewtext'])
df
# Out:
#       customer_name  customerid  productid    action  rating  \
# 0     Daniel Miller          34          8      View       1
# 1     Daniel Miller          34          8      View       1
# 2       David Lopez          77          6  Drop-off       2
# 3      Olivia Smith          78         20      View       2
# 4       David Lopez          77          6  Drop-off       3
# ..              ...         ...        ...       ...     ...
# 95     David Thomas          33         18  Drop-off       5
# 96     Olivia Brown          44         18      View       5
# 97  Sophia Anderson          29          3      View       5
# 98     David Thomas          33         18  Drop-off       5
# 99      Alex Wilson          22          9      View       5
#
#                                            reviewtext
# 0    I  had  a  bad  experience  with  this  product.
# 1                             Not  worth  the  money.
# 2        Product  did    not  meet  my  expectations.
# ...
